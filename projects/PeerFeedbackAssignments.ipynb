# %% [markdown]
# # Assignment of peer feedback
#
# This notebook contains the code used to determine which two other teams each team must give feed back to in the data project

# %%
#!pip install PyGithub

# %%
from github import Github 
import sys
import datetime
import pandas as pd
import numpy as np
import random
from collections import Counter

# %%
# Access github through access token. This one has been destroyed be Github for safety reasons.
gh = Github('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')
org = gh.get_organization('NumEconCopenhagen')
all_repos = org.get_repos()
active_repos = {}
date0 = datetime.datetime(2021, 3, 20)
handin_date = datetime.datetime(2021, 5, 13)
disregard_repos = ['Projects_workfolder', 
                    'Suggested-Solutions-2021', 
                    'The-Danish-German-Alliance', 
                    'cahm-old-',
                    'Group-Sara']

# %%
# Function to test whether activity has been recorded since active date in specific project
def check_activity(repo, project, active_repos, start_date, handin_date):
    try:
        commits = repo.get_commits(since = start_date, until = handin_date)
        for commit in commits:
            for cf in commit.files:
                if project in cf.filename:
                    active_repos[repo.name] = repo
                    return active_repos
    except:
        pass    
    return active_repos

# %%
# Add active repos to dictionary
for i,repo in enumerate(all_repos):
    if repo.name in disregard_repos:
        continue        
    print('processing repo', str(i), 'out of', str(all_repos.totalCount), end = '\r')
    
    # Run function to test presence an active data project
    active_repos = check_activity(repo, 'dataproject', active_repos, date0, handin_date)
# Out:
# processing repo 183 out of 185

# %%
# Get team names and write out all active repos
teams = []
for k in active_repos.keys():
    print(k)
    teams.append(k.replace('projects-2021-', ''))
# Out:
# projects-2021-concatenaters
# projects-2021-hello
# projects-2021-CH13FSQD
# projects-2021-luna-hjerteknuser
# projects-2021-programmorerne
# projects-2021-team-mej
# projects-2021-team-olm
# projects-2021-egpk
# projects-2021-ska
# projects-2021-fgs
# projects-2021-mms
# projects-2021-team-kan-du-kode-eller-hvad
# projects-2021-regnefaetrene
# projects-2021-Numpy
# projects-2021-unicorns_1
# projects-2021-double-a
# projects-2021-hold-j1
# projects-2021-aristochats
# projects-2021-sft
# projects-2021-m-m
# projects-2021-sstl
# Inaugural-Project-2021_BSJH
# projects-2021-california-sunshine
# projects-2021-west-wing
# projects-2021-team-easy-on
# projects-2021-mogens-pa-linkedin
# projects-2021-holdfast
# projects-2021-m-a-c-h
# projects-2021-lions
# projects-2021-monty-python-1
# projects-2021-hold-i-nakken
# projects-2021-kera
# projects-2021-mf
# projects-2021-sev
# projects-2021-hello-world
# projects-2021-stressfaktoren
# projects-2021-cr-and-gb
# projects-2021-the-danish-german-alliance
# projects-2021-a12
# projects-2021-team-tons
# projects-2021-bjs201
# projects-2021-econ-jedi
# projects-2021-python-gurlz
# projects-2021-Group-Sara
# projects-2021-group-sara-1
# projects-2021-cahm-old-
# projects-2021-stronk

# %%
teams
# Out:
# ['concatenaters',
#  'hello',
#  'CH13FSQD',
#  'luna-hjerteknuser',
#  'programmorerne',
#  'team-mej',
#  'team-olm',
#  'egpk',
#  'ska',
#  'fgs',
#  'mms',
#  'team-kan-du-kode-eller-hvad',
#  'regnefaetrene',
#  'Numpy',
#  'unicorns_1',
#  'double-a',
#  'hold-j1',
#  'aristochats',
#  'sft',
#  'm-m',
#  'sstl',
#  'Inaugural-Project-2021_BSJH',
#  'california-sunshine',
#  'west-wing',
#  'team-easy-on',
#  'mogens-pa-linkedin',
#  'holdfast',
#  'm-a-c-h',
#  'lions',
#  'monty-python-1',
#  'hold-i-nakken',
#  'kera',
#  'mf',
#  'sev',
#  'hello-world',
#  'stressfaktoren',
#  'cr-and-gb',
#  'the-danish-german-alliance',
#  'a12',
#  'team-tons',
#  'bjs201',
#  'econ-jedi',
#  'python-gurlz',
#  'Group-Sara',
#  'group-sara-1',
#  'cahm-old-',
#  'stronk']

# %%
# Create data frame for storing assignment
random.seed(1)
teams_df = pd.DataFrame(data = teams, columns = ['team'])
irrelevant = teams_df.team.isin(disregard_repos)
teams_df = teams_df.loc[np.invert(irrelevant),:]
teams_df.sort_values(by = 'team', inplace = True)
teams_df.reset_index(drop=True, inplace=True)
teams_df['peer_group_1'] = np.nan
teams_df['peer_group_2'] = np.nan
display(teams_df)
# Out:
#                            team  peer_group_1  peer_group_2
# 0                      CH13FSQD           NaN           NaN
# 1   Inaugural-Project-2021_BSJH           NaN           NaN
# 2                         Numpy           NaN           NaN
# 3                           a12           NaN           NaN
# 4                   aristochats           NaN           NaN
# 5                        bjs201           NaN           NaN
# 6           california-sunshine           NaN           NaN
# 7                 concatenaters           NaN           NaN
# 8                     cr-and-gb           NaN           NaN
# 9                      double-a           NaN           NaN
# 10                    econ-jedi           NaN           NaN
# 11                         egpk           NaN           NaN
# 12                          fgs           NaN           NaN
# 13                 group-sara-1           NaN           NaN
# 14                        hello           NaN           NaN
# 15                  hello-world           NaN           NaN
# 16                hold-i-nakken           NaN           NaN
# 17                      hold-j1           NaN           NaN
# 18                     holdfast           NaN           NaN
# 19                         kera           NaN           NaN
# 20                        lions           NaN           NaN
# 21            luna-hjerteknuser           NaN           NaN
# 22                      m-a-c-h           NaN           NaN
# 23                          m-m           NaN           NaN
# 24                           mf           NaN           NaN
# 25                          mms           NaN           NaN
# 26           mogens-pa-linkedin           NaN           NaN
# 27               monty-python-1           NaN           NaN
# 28               programmorerne           NaN           NaN
# 29                 python-gurlz           NaN           NaN
# 30                regnefaetrene           NaN           NaN
# 31                          sev           NaN           NaN
# 32                          sft           NaN           NaN
# 33                          ska           NaN           NaN
# 34                         sstl           NaN           NaN
# 35               stressfaktoren           NaN           NaN
# 36                       stronk           NaN           NaN
# 37                 team-easy-on           NaN           NaN
# 38  team-kan-du-kode-eller-hvad           NaN           NaN
# 39                     team-mej           NaN           NaN
# 40                     team-olm           NaN           NaN
# 41                    team-tons           NaN           NaN
# 42   the-danish-german-alliance           NaN           NaN
# 43                   unicorns_1           NaN           NaN
# 44                    west-wing           NaN           NaN

# %%
# Algorithm for assigning peers to teams
N = len(teams_df.team.values)
counter = [0 for _ in range(N)]
assigned = []

# For each team, loop over teams that have not already been assigned
for i,_ in enumerate(teams_df.team):
    pop = [t for t in range(N) if (t != i) & (t not in assigned)]
    peers = random.sample(pop, 2)    
    for c in [0,1]:
        teams_df.iloc[i, 1 + c] = teams_df.team[peers[c]]
        counter[peers[c]] += 1
        if counter[peers[c]] == 2:
            assigned.append(peers[c])

display(teams_df)
# Out:
#                            team                 peer_group_1  \
# 0                      CH13FSQD                     double-a
# 1   Inaugural-Project-2021_BSJH                       bjs201
# 2                         Numpy                    cr-and-gb
# 3                           a12                 python-gurlz
# 4                   aristochats   the-danish-german-alliance
# 5                        bjs201                        hello
# 6           california-sunshine                          sft
# 7                 concatenaters                          mms
# 8                     cr-and-gb                    team-tons
# 9                      double-a                regnefaetrene
# 10                    econ-jedi                  hello-world
# 11                         egpk          california-sunshine
# 12                          fgs  Inaugural-Project-2021_BSJH
# 13                 group-sara-1  team-kan-du-kode-eller-hvad
# 14                        hello               programmorerne
# 15                  hello-world                          ska
# 16                hold-i-nakken                     team-mej
# 17                      hold-j1                         sstl
# 18                     holdfast                   unicorns_1
# 19                         kera                 python-gurlz
# 20                        lions                         kera
# 21            luna-hjerteknuser                           mf
# 22                      m-a-c-h  team-kan-du-kode-eller-hvad
# 23                          m-m                    cr-and-gb
# 24                           mf                     team-mej
# 25                          mms                        hello
# 26           mogens-pa-linkedin                   unicorns_1
# 27               monty-python-1   the-danish-german-alliance
# 28               programmorerne                          m-m
# 29                 python-gurlz                    team-tons
# 30                regnefaetrene                         kera
# 31                          sev               stressfaktoren
# 32                          sft                         sstl
# 33                          ska                  aristochats
# 34                         sstl                 group-sara-1
# 35               stressfaktoren                          fgs
# 36                       stronk                       bjs201
# 37                 team-easy-on                      m-a-c-h
# 38  team-kan-du-kode-eller-hvad                       stronk
# 39                     team-mej                  aristochats
# 40                     team-olm                concatenaters
# 41                    team-tons                    econ-jedi
# 42   the-danish-german-alliance                        lions
# 43                   unicorns_1                    econ-jedi
# 44                    west-wing                          ska
#
#                    peer_group_2
# 0                  team-easy-on
# 1                       hold-j1
# 2                           sft
# 3                           sev
# 4                           mms
# 5                 concatenaters
# 6   Inaugural-Project-2021_BSJH
# 7                programmorerne
# 8                      CH13FSQD
# 9                      holdfast
# 10                     team-olm
# 11            luna-hjerteknuser
# 12                    west-wing
# 13                     CH13FSQD
# 14                hold-i-nakken
# 15                          a12
# 16                      hold-j1
# 17                 team-easy-on
# 18                hold-i-nakken
# 19                     holdfast
# 20                     team-olm
# 21                          a12
# 22                     double-a
# 23                          sev
# 24                    west-wing
# 25          california-sunshine
# 26                        lions
# 27                regnefaetrene
# 28               monty-python-1
# 29                          fgs
# 30                       stronk
# 31               monty-python-1
# 32                          m-m
# 33                 group-sara-1
# 34                           mf
# 35                      m-a-c-h
# 36                         egpk
# 37               stressfaktoren
# 38                  hello-world
# 39           mogens-pa-linkedin
# 40           mogens-pa-linkedin
# 41            luna-hjerteknuser
# 42                         egpk
# 43                        Numpy
# 44                        Numpy

# %%
# Test that everyone are assigned to exactly 2 groups
peergroups = teams_df.peer_group_1.values.tolist() + teams_df.peer_group_2.values.tolist()
counts = Counter(peergroups)
print('Everyone is assigned to exactly 2 groups?: ', set(counts.values()) == {2})
# Out:
# Everyone is assigned to exactly 2 groups?:  True

# %% [markdown]
# Store the resulting list in excel file available on MS Teams

# %%
teams_df.to_excel('Model Project - peer assignment.xlsx', sheet_name='Data project', index = False)
