# %% [markdown]
# # Assignment of peer feedback
#
# This notebook contains the code used to determine which two other teams each team must give feed back to in the data project

# %%
#!pip install PyGithub

# %%
from github import Github 
import sys
import datetime
import pandas as pd
import numpy as np
import random
from collections import Counter

# %%
# Access github through access token. This one has only read access.
gh = Github('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')
org = gh.get_organization('NumEconCopenhagen')
all_repos = org.get_repos()
active_repos = {}
march2021 = datetime.datetime(2021, 3, 25)
handin_date = datetime.datetime(2021, 4, 12)
disregard_repos = ['Projects_workfolder', 'Suggested-Solutions-2021']

# %%
# Function to test whether activity has been recorded since active date in specific project
def check_activity(repo, project, active_repos, start_date, handin_date):
    try:
        commits = repo.get_commits(since = start_date, until = handin_date)
        for commit in commits:
            for cf in commit.files:
                if project in cf.filename:
                    active_repos[repo.name] = repo
                    return active_repos
    except:
        pass    
    return active_repos

# %%
# Add active repos to dictionary
for i,repo in enumerate(all_repos):
    if repo.name in disregard_repos:
        continue        
    print('processing repo', str(i), 'out of', str(all_repos.totalCount), end = '\r')
    
    # Run function to test presence an active data project
    active_repos = check_activity(repo, 'dataproject', active_repos, march2021, handin_date)
# Out:
# processing repo 184 out of 186

# %%
# Get team names and write out all active repos
teams = []
for k in active_repos.keys():
    print(k)
    teams.append(k.replace('projects-2021-', ''))
# Out:
# projects-2021-concatenaters
# projects-2021-hello
# projects-2021-CH13FSQD
# projects-2021-luna-hjerteknuser
# projects-2021-programmorerne
# projects-2021-team-mej
# projects-2021-team-olm
# projects-2021-egpk
# projects-2021-ska
# EGPK
# projects-2021-fgs
# projects-2021-mms
# projects-2021-team-kan-du-kode-eller-hvad
# projects-2021-regnefaetrene
# projects-2021-Numpy
# projects-2021-unicorns_1
# projects-2021-double-a
# The-Danish-German-Alliance
# projects-2021-hold-j1
# projects-2021-aristochats
# projects-2021-sft
# projects-2021-m-m
# projects-2021-sstl
# Inaugural-Project-2021_BSJH
# projects-2021-california-sunshine
# projects-2021-west-wing
# projects-2021-team-easy-on
# projects-2021-mogens-pa-linkedin
# projects-2021-holdfast
# projects-2021-m-a-c-h
# projects-2021-lions
# projects-2021-monty-python-1
# projects-2021-hold-i-nakken
# projects-2021-kera
# projects-2021-mf
# projects-2021-sev
# projects-2021-hello-world
# projects-2021-stressfaktoren
# projects-2021-cr-and-gb
# projects-2021-the-danish-german-alliance
# projects-2021-a12
# projects-2021-team-tons
# projects-2021-econ-jedi
# projects-2021-python-gurlz
# projects-2021-group-sara-1
# projects-2021-stronk

# %%
# Create data frame for storing assignment
random.seed(0)
teams_df = pd.DataFrame(data = teams, columns = ['team'])
teams_df.sort_values(by = 'team', inplace = True)
teams_df.reset_index(inplace = True, drop = True)
teams_df['peer_group_1'] = np.nan
teams_df['peer_group_2'] = np.nan
display(teams_df)
# Out:
#                            team  peer_group_1  peer_group_2
# 0                      CH13FSQD           NaN           NaN
# 1                          EGPK           NaN           NaN
# 2   Inaugural-Project-2021_BSJH           NaN           NaN
# 3                         Numpy           NaN           NaN
# 4    The-Danish-German-Alliance           NaN           NaN
# 5                           a12           NaN           NaN
# 6                   aristochats           NaN           NaN
# 7           california-sunshine           NaN           NaN
# 8                 concatenaters           NaN           NaN
# 9                     cr-and-gb           NaN           NaN
# 10                     double-a           NaN           NaN
# 11                    econ-jedi           NaN           NaN
# 12                         egpk           NaN           NaN
# 13                          fgs           NaN           NaN
# 14                 group-sara-1           NaN           NaN
# 15                        hello           NaN           NaN
# 16                  hello-world           NaN           NaN
# 17                hold-i-nakken           NaN           NaN
# 18                      hold-j1           NaN           NaN
# 19                     holdfast           NaN           NaN
# 20                         kera           NaN           NaN
# 21                        lions           NaN           NaN
# 22            luna-hjerteknuser           NaN           NaN
# 23                      m-a-c-h           NaN           NaN
# 24                          m-m           NaN           NaN
# 25                           mf           NaN           NaN
# 26                          mms           NaN           NaN
# 27           mogens-pa-linkedin           NaN           NaN
# 28               monty-python-1           NaN           NaN
# 29               programmorerne           NaN           NaN
# 30                 python-gurlz           NaN           NaN
# 31                regnefaetrene           NaN           NaN
# 32                          sev           NaN           NaN
# 33                          sft           NaN           NaN
# 34                          ska           NaN           NaN
# 35                         sstl           NaN           NaN
# 36               stressfaktoren           NaN           NaN
# 37                       stronk           NaN           NaN
# 38                 team-easy-on           NaN           NaN
# 39  team-kan-du-kode-eller-hvad           NaN           NaN
# 40                     team-mej           NaN           NaN
# 41                     team-olm           NaN           NaN
# 42                    team-tons           NaN           NaN
# 43   the-danish-german-alliance           NaN           NaN
# 44                   unicorns_1           NaN           NaN
# 45                    west-wing           NaN           NaN

# %%
# Algorithm for assigning peers to teams
N = len(teams_df.team.values)
counter = [0 for _ in range(N)]
assigned = []

# For each team, loop over teams that have not already been assigned
for i,_ in enumerate(teams_df.team):
    pop = [t for t in range(N) if (t != i) & (t not in assigned)]
    peers = random.sample(pop, 2)    
    for c in [0,1]:
        teams_df.iloc[i, 1 + c] = teams_df.team[peers[c]]
        counter[peers[c]] += 1
        if counter[peers[c]] == 2:
            assigned.append(peers[c])

display(teams_df)
# Out:
#                            team                 peer_group_1  \
# 0                      CH13FSQD                           mf
# 1                          EGPK                        Numpy
# 2   Inaugural-Project-2021_BSJH                          sft
# 3                         Numpy                          mms
# 4    The-Danish-German-Alliance                regnefaetrene
# 5                           a12                 team-easy-on
# 6                   aristochats                          sft
# 7           california-sunshine                     holdfast
# 8                 concatenaters                  aristochats
# 9                     cr-and-gb                hold-i-nakken
# 10                     double-a                    team-tons
# 11                    econ-jedi            luna-hjerteknuser
# 12                         egpk   The-Danish-German-Alliance
# 13                          fgs               stressfaktoren
# 14                 group-sara-1          california-sunshine
# 15                        hello                          ska
# 16                  hello-world                        hello
# 17                hold-i-nakken                       stronk
# 18                      hold-j1   the-danish-german-alliance
# 19                     holdfast                        Numpy
# 20                         kera          california-sunshine
# 21                        lions                     CH13FSQD
# 22            luna-hjerteknuser                     team-mej
# 23                      m-a-c-h                        hello
# 24                          m-m                 team-easy-on
# 25                           mf                         sstl
# 26                          mms   The-Danish-German-Alliance
# 27           mogens-pa-linkedin                 python-gurlz
# 28               monty-python-1                  hello-world
# 29               programmorerne                         sstl
# 30                 python-gurlz                          a12
# 31                regnefaetrene                       stronk
# 32                          sev                concatenaters
# 33                          sft                     team-mej
# 34                          ska                concatenaters
# 35                         sstl                      hold-j1
# 36               stressfaktoren                          mms
# 37                       stronk               programmorerne
# 38                 team-easy-on               monty-python-1
# 39  team-kan-du-kode-eller-hvad                    west-wing
# 40                     team-mej                      hold-j1
# 41                     team-olm                          a12
# 42                    team-tons                          fgs
# 43   the-danish-german-alliance                         EGPK
# 44                   unicorns_1  team-kan-du-kode-eller-hvad
# 45                    west-wing  team-kan-du-kode-eller-hvad
#
#                    peer_group_2
# 0            mogens-pa-linkedin
# 1                 hold-i-nakken
# 2                           sev
# 3                          kera
# 4                       m-a-c-h
# 5                  group-sara-1
# 6                     cr-and-gb
# 7                     cr-and-gb
# 8                     team-tons
# 9                stressfaktoren
# 10                    econ-jedi
# 11                  aristochats
# 12                           mf
# 13                     team-olm
# 14           mogens-pa-linkedin
# 15                          m-m
# 16                   unicorns_1
# 17                          ska
# 18                         kera
# 19                     CH13FSQD
# 20                          sev
# 21                    west-wing
# 22                     team-olm
# 23                         egpk
# 24                  hello-world
# 25                   unicorns_1
# 26                    econ-jedi
# 27                 group-sara-1
# 28                     double-a
# 29               monty-python-1
# 30            luna-hjerteknuser
# 31                 python-gurlz
# 32                        lions
# 33                        lions
# 34                          m-m
# 35                regnefaetrene
# 36                      m-a-c-h
# 37                         egpk
# 38  Inaugural-Project-2021_BSJH
# 39                     holdfast
# 40                     double-a
# 41  Inaugural-Project-2021_BSJH
# 42   the-danish-german-alliance
# 43               programmorerne
# 44                          fgs
# 45                         EGPK

# %%
# Test that everyone are assigned to exactly 2 groups
peergroups = teams_df.peer_group_1.values.tolist() + teams_df.peer_group_2.values.tolist()
counts = Counter(peergroups)
print('Everyone is assigned to exactly 2 groups?: ', set(counts.values()) == {2})
# Out:
# Everyone is assigned to exactly 2 groups?:  True

# %% [markdown]
# Store the resulting list in excel file available on MS Teams

# %%
teams_df.to_excel('Data Project - peer assignment.xlsx', sheet_name='Data project', index = False)
